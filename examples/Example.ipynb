# %% [markdown]
# # This is an Example of how to use osmpoi library
# ## Importing the Libraries

# %%
# This is collecting the osmpoi package from parent directory
import sys
sys.path.append("..")

# This is what you would need to import
import osmpoi

# %% [markdown]
# ### The data.json will automatically generate if it does not exist where the python file is
#
# ### To request an region you will need bounding box co-ordinates using bboxfinder can be useful for this. It will be in the order of: min_long, min_lat, max_long, max_lat when doing a function
#
# ### Text-based output

# %% [markdown]
# This is how you would get points of interest within a region back as a dictionary

# %%
retrieve.pois_bbox(-3.5399, 50.7342, -3.4890, 50.7150)
# Out:
# {'Area': '-3.539900,50.734200,-3.489000,50.715000',
#  'Timestamp': '2023-03-02 14:58',
#  'Sustenance': 22,
#  'Education': 299,
#  'Transportation': 31,
#  'Financial': 13,
#  'Healthcare': 62,
#  'Entertainment': 15,
#  'Public Services': 27,
#  'Facilities': 16,
#  'Waste Management': 0,
#  'Other': 159,
#  'Total': 644}

# %% [markdown]
# You can also get it back as a percentage

# %%
retrieve.pois_percent(-3.5399, 50.7342, -3.4890, 50.7150)
# Out:
# {'Area': '-3.539900,50.734200,-3.489000,50.715000',
#  'Timestamp': '2023-03-02 14:58',
#  'Sustenance': '3.42%',
#  'Education': '46.43%',
#  'Transportation': '4.81%',
#  'Financial': '2.02%',
#  'Healthcare': '9.63%',
#  'Entertainment': '2.33%',
#  'Public Services': '4.19%',
#  'Facilities': '2.48%',
#  'Waste Management': '0.0%',
#  'Other': '24.69%',
#  'Total': 644}

# %% [markdown]
# ### Plotting

# %% [markdown]
# This need to get more than 1 region to do tests on

# %%
region1 = retrieve.pois_bbox(-3.5399, 50.7342, -3.4890, 50.7150)
region2 = retrieve.pois_bbox(-3.4911, 50.8225, -3.4657, 50.8129)

# %% [markdown]
# Now to plot one of these regions

# %%
plotter.plot(region1)

# %%
plotter.plot(region2)

# %% [markdown]
# To Compare these graphs you can use the compare function

# %%
plotter.compare(region1, region2)
